# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns  
# %matplotlib inline

# %%
faostat_df = pd.read_csv("F:\Dataframes\Global Warming\FAOSTAT_data_1-10-2022.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000001?line=0'>1</a> faostat_df = pd.read_csv("F:\Dataframes\Global Warming\FAOSTAT_data_1-10-2022.csv")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F:\\Dataframes\\Global Warming\\FAOSTAT_data_1-10-2022.csv'

# %%
faostat_df.head()
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change                2  Afghanistan          7271
# 4          ET  Temperature change                2  Afghanistan          7271
#
#               Element  Months Code   Months  Year Code  Year Unit  Value Flag  \
# 0  Temperature change         7001  January       1961  1961   ?C  0.746   Fc
# 1  Temperature change         7001  January       1962  1962   ?C  0.009   Fc
# 2  Temperature change         7001  January       1963  1963   ?C  2.695   Fc
# 3  Temperature change         7001  January       1964  1964   ?C -5.277   Fc
# 4  Temperature change         7001  January       1965  1965   ?C  1.827   Fc
#
#   Flag Description
# 0  Calculated data
# 1  Calculated data
# 2  Calculated data
# 3  Calculated data
# 4  Calculated data

# %%
#Lowest temperatures changes by country
faostat_df.groupby("Area")["Value"].min()
# Out:
# Area
# Afghanistan      -7.724
# Albania          -4.334
# Algeria          -2.769
# American Samoa   -1.183
# Andorra          -4.555
#                   ...
# Western Sahara   -3.100
# Yemen            -1.369
# Yugoslav SFR     -4.800
# Zambia           -1.657
# Zimbabwe         -2.330
# Name: Value, Length: 247, dtype: float64

# %%
#Highest temperatures changes by country
faostat_df.groupby("Area")["Value"].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000004?line=0'>1</a> #Highest temperatures changes by country
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000004?line=1'>2</a> faostat_df.groupby("Area")["Value"].max()
#
# NameError: name 'faostat_df' is not defined

# %%
##Biggest change of lowest temperature 
faostat_df[faostat_df["Value"]==-9.303]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000005?line=0'>1</a> ##Biggest change of lowest temperature
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000005?line=1'>2</a> faostat_df[faostat_df["Value"]==-9.303]
#
# NameError: name 'faostat_df' is not defined

# %%
faostat_df.describe()
# Out:
#        Area Code (FAO)  Element Code    Months Code      Year Code  \
# count    229925.000000      229925.0  229925.000000  229925.000000
# mean        130.647689        7271.0    7009.882353    1991.306248
# std          76.809008           0.0       6.037955      17.333252
# min           1.000000        7271.0    7001.000000    1961.000000
# 25%          64.000000        7271.0    7005.000000    1976.000000
# 50%         131.000000        7271.0    7009.000000    1992.000000
# 75%         194.000000        7271.0    7016.000000    2006.000000
# max         351.000000        7271.0    7020.000000    2020.000000
#
#                 Year          Value
# count  229925.000000  222012.000000
# mean     1991.306248       0.492626
# std        17.333252       1.036364
# min      1961.000000      -9.303000
# 25%      1976.000000      -0.071000
# 50%      1992.000000       0.414000
# 75%      2006.000000       0.999000
# max      2020.000000      11.759000

# %%
faostat_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000007?line=0'>1</a> faostat_df.info()
#
# NameError: name 'faostat_df' is not defined

# %%
group_country = faostat_df[["Area","Months","Year", "Value"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000008?line=0'>1</a> group_country = faostat_df[["Area","Months","Year", "Value"]]
#
# NameError: name 'faostat_df' is not defined

# %%
group_year = group_country.groupby(["Year"]).mean()

# %%
group_year
# Out:
#          Value
# Year
# 1961  0.144699
# 1962 -0.035784
# 1963 -0.030519
# 1964 -0.115801
# 1965 -0.221856
# 1966  0.108907
# 1967 -0.126955
# 1968 -0.164114
# 1969  0.126069
# 1970  0.084453
# 1971 -0.183408
# 1972 -0.050052
# 1973  0.190302
# 1974 -0.123036
# 1975 -0.034646
# 1976 -0.207629
# 1977  0.181426
# 1978  0.053469
# 1979  0.217557
# 1980  0.198889
# 1981  0.194418
# 1982  0.152091
# 1983  0.338641
# 1984  0.076794
# 1985  0.066933
# 1986  0.112895
# 1987  0.406208
# 1988  0.417302
# 1989  0.272393
# 1990  0.556680
# 1991  0.321367
# 1992  0.249733
# 1993  0.229879
# 1994  0.571032
# 1995  0.585426
# 1996  0.297808
# 1997  0.554161
# 1998  0.945291
# 1999  0.730058
# 2000  0.676256
# 2001  0.808911
# 2002  0.907633
# 2003  0.843181
# 2004  0.770325
# 2005  0.848328
# 2006  0.875178
# 2007  0.975491
# 2008  0.796008
# 2009  0.923137
# 2010  1.050006
# 2011  0.834942
# 2012  0.874836
# 2013  0.937344
# 2014  1.119342
# 2015  1.299005
# 2016  1.407707
# 2017  1.266360
# 2018  1.302246
# 2019  1.452609
# 2020  1.500217

# %%
import matplotlib
from matplotlib.pyplot import figure
figure(figsize=(14,5))
sns.lineplot(data=group_year,x="Year",y="Value",label="AVG World")
sns.lineplot(data=mexico_year,x="Year",y="Value",label="AVG Mexico")
matplotlib.pyplot.title("AVG Temperature Change(1960-2020)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb Cell 12 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000011?line=1'>2</a> from matplotlib.pyplot import figure
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000011?line=2'>3</a> figure(figsize=(14,5))
# ----> <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000011?line=3'>4</a> sns.lineplot(data=group_year,x="Year",y="Value",label="AVG World")
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000011?line=4'>5</a> sns.lineplot(data=mexico_year,x="Year",y="Value",label="AVG Mexico")
#       <a href='vscode-notebook-cell:/Users/raulandresmoch/Documents/GitHub/Global_Warming_Analysis/global_warming_analysis.ipynb#ch0000011?line=5'>6</a> matplotlib.pyplot.title("AVG Temperature Change(1960-2020)")
#
# NameError: name 'group_year' is not defined

# %%
mexico_temp=group_country[group_country["Area"]=="Mexico"]

# %%
mexico_year = mexico_temp.groupby("Year").mean()

# %%
mexico_df = faostat_df.loc[faostat_df["Area"]=="Mexico"]

# %%
min_mex=mexico_df["Value"].min()
print(f"Mexico lowest change in themperature was: {min_mex}")
# Out:
# Mexico lowest change in themperature was: -1.58

# %%
max_mex=mexico_df["Value"].max()
print(f"Mexico highest change in themperature was: {max_mex}")
# Out:
# Mexico highest change in themperature was: 2.632

# %%
mexico_df[mexico_df["Value"]== -1.58]
# Out:
#        Domain Code              Domain  Area Code (FAO)    Area  Element Code  \
# 131333          ET  Temperature change              138  Mexico          7271
#
#                    Element  Months Code Months  Year Code  Year Unit  Value  \
# 131333  Temperature change         7003  March       1968  1968   ?C  -1.58
#
#        Flag Flag Description
# 131333   Fc  Calculated data

# %%
mexico_df[mexico_df["Value"]== 2.632]
# Out:
#        Domain Code              Domain  Area Code (FAO)    Area  Element Code  \
# 131322          ET  Temperature change              138  Mexico          7271
#
#                    Element  Months Code    Months  Year Code  Year Unit  \
# 131322  Temperature change         7002  February       2017  2017   ?C
#
#         Value Flag Flag Description
# 131322  2.632   Fc  Calculated data

# %%
main_df=pd.read_csv('/Users/raulandresmoch/Documents/Pyton/global_warming/Environment_Temperature_change_E_All_Data_NOFLAG.csv',encoding="ISO-8859-1")

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Data columns (total 66 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     9656 non-null   int64
#  1   Area          9656 non-null   object
#  2   Months Code   9656 non-null   int64
#  3   Months        9656 non-null   object
#  4   Element Code  9656 non-null   int64
#  5   Element       9656 non-null   object
#  6   Unit          9656 non-null   object
#  7   Y1961         8287 non-null   float64
#  8   Y1962         8322 non-null   float64
#  9   Y1963         8294 non-null   float64
#  10  Y1964         8252 non-null   float64
#  11  Y1965         8281 non-null   float64
#  12  Y1966         8364 non-null   float64
#  13  Y1967         8347 non-null   float64
#  14  Y1968         8345 non-null   float64
#  15  Y1969         8326 non-null   float64
#  16  Y1970         8308 non-null   float64
#  17  Y1971         8303 non-null   float64
#  18  Y1972         8323 non-null   float64
#  19  Y1973         8394 non-null   float64
#  20  Y1974         8374 non-null   float64
#  21  Y1975         8280 non-null   float64
#  22  Y1976         8209 non-null   float64
#  23  Y1977         8257 non-null   float64
#  24  Y1978         8327 non-null   float64
#  25  Y1979         8290 non-null   float64
#  26  Y1980         8283 non-null   float64
#  27  Y1981         8276 non-null   float64
#  28  Y1982         8237 non-null   float64
#  29  Y1983         8205 non-null   float64
#  30  Y1984         8259 non-null   float64
#  31  Y1985         8216 non-null   float64
#  32  Y1986         8268 non-null   float64
#  33  Y1987         8284 non-null   float64
#  34  Y1988         8273 non-null   float64
#  35  Y1989         8257 non-null   float64
#  36  Y1990         8239 non-null   float64
#  37  Y1991         8158 non-null   float64
#  38  Y1992         8354 non-null   float64
#  39  Y1993         8315 non-null   float64
#  40  Y1994         8373 non-null   float64
#  41  Y1995         8409 non-null   float64
#  42  Y1996         8439 non-null   float64
#  43  Y1997         8309 non-null   float64
#  44  Y1998         8370 non-null   float64
#  45  Y1999         8324 non-null   float64
#  46  Y2000         8342 non-null   float64
#  47  Y2001         8241 non-null   float64
#  48  Y2002         8312 non-null   float64
#  49  Y2003         8390 non-null   float64
#  50  Y2004         8415 non-null   float64
#  51  Y2005         8424 non-null   float64
#  52  Y2006         8503 non-null   float64
#  53  Y2007         8534 non-null   float64
#  54  Y2008         8475 non-null   float64
#  55  Y2009         8419 non-null   float64
#  56  Y2010         8435 non-null   float64
#  57  Y2011         8437 non-null   float64
#  58  Y2012         8350 non-null   float64
#  59  Y2013         8427 non-null   float64
#  60  Y2014         8377 non-null   float64
#  61  Y2015         8361 non-null   float64
#  62  Y2016         8348 non-null   float64
#  63  Y2017         8366 non-null   float64
#  64  Y2018         8349 non-null   float64
#  65  Y2019         8365 non-null   float64
# dtypes: float64(59), int64(3), object(4)
# memory usage: 4.9+ MB

# %%
main_df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 1  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2  1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 3  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
#
# [5 rows x 66 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Data columns (total 66 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     9656 non-null   int64
#  1   Area          9656 non-null   object
#  2   Months Code   9656 non-null   int64
#  3   Months        9656 non-null   object
#  4   Element Code  9656 non-null   int64
#  5   Element       9656 non-null   object
#  6   Unit          9656 non-null   object
#  7   Y1961         8287 non-null   float64
#  8   Y1962         8322 non-null   float64
#  9   Y1963         8294 non-null   float64
#  10  Y1964         8252 non-null   float64
#  11  Y1965         8281 non-null   float64
#  12  Y1966         8364 non-null   float64
#  13  Y1967         8347 non-null   float64
#  14  Y1968         8345 non-null   float64
#  15  Y1969         8326 non-null   float64
#  16  Y1970         8308 non-null   float64
#  17  Y1971         8303 non-null   float64
#  18  Y1972         8323 non-null   float64
#  19  Y1973         8394 non-null   float64
#  20  Y1974         8374 non-null   float64
#  21  Y1975         8280 non-null   float64
#  22  Y1976         8209 non-null   float64
#  23  Y1977         8257 non-null   float64
#  24  Y1978         8327 non-null   float64
#  25  Y1979         8290 non-null   float64
#  26  Y1980         8283 non-null   float64
#  27  Y1981         8276 non-null   float64
#  28  Y1982         8237 non-null   float64
#  29  Y1983         8205 non-null   float64
#  30  Y1984         8259 non-null   float64
#  31  Y1985         8216 non-null   float64
#  32  Y1986         8268 non-null   float64
#  33  Y1987         8284 non-null   float64
#  34  Y1988         8273 non-null   float64
#  35  Y1989         8257 non-null   float64
#  36  Y1990         8239 non-null   float64
#  37  Y1991         8158 non-null   float64
#  38  Y1992         8354 non-null   float64
#  39  Y1993         8315 non-null   float64
#  40  Y1994         8373 non-null   float64
#  41  Y1995         8409 non-null   float64
#  42  Y1996         8439 non-null   float64
#  43  Y1997         8309 non-null   float64
#  44  Y1998         8370 non-null   float64
#  45  Y1999         8324 non-null   float64
#  46  Y2000         8342 non-null   float64
#  47  Y2001         8241 non-null   float64
#  48  Y2002         8312 non-null   float64
#  49  Y2003         8390 non-null   float64
#  50  Y2004         8415 non-null   float64
#  51  Y2005         8424 non-null   float64
#  52  Y2006         8503 non-null   float64
#  53  Y2007         8534 non-null   float64
#  54  Y2008         8475 non-null   float64
#  55  Y2009         8419 non-null   float64
#  56  Y2010         8435 non-null   float64
#  57  Y2011         8437 non-null   float64
#  58  Y2012         8350 non-null   float64
#  59  Y2013         8427 non-null   float64
#  60  Y2014         8377 non-null   float64
#  61  Y2015         8361 non-null   float64
#  62  Y2016         8348 non-null   float64
#  63  Y2017         8366 non-null   float64
#  64  Y2018         8349 non-null   float64
#  65  Y2019         8365 non-null   float64
# dtypes: float64(59), int64(3), object(4)
# memory usage: 4.9+ MB

# %%
list(main_df.columns)
# Out:
# ['Area Code',
#  'Area',
#  'Months Code',
#  'Months',
#  'Element Code',
#  'Element',
#  'Unit',
#  'Y1961',
#  'Y1962',
#  'Y1963',
#  'Y1964',
#  'Y1965',
#  'Y1966',
#  'Y1967',
#  'Y1968',
#  'Y1969',
#  'Y1970',
#  'Y1971',
#  'Y1972',
#  'Y1973',
#  'Y1974',
#  'Y1975',
#  'Y1976',
#  'Y1977',
#  'Y1978',
#  'Y1979',
#  'Y1980',
#  'Y1981',
#  'Y1982',
#  'Y1983',
#  'Y1984',
#  'Y1985',
#  'Y1986',
#  'Y1987',
#  'Y1988',
#  'Y1989',
#  'Y1990',
#  'Y1991',
#  'Y1992',
#  'Y1993',
#  'Y1994',
#  'Y1995',
#  'Y1996',
#  'Y1997',
#  'Y1998',
#  'Y1999',
#  'Y2000',
#  'Y2001',
#  'Y2002',
#  'Y2003',
#  'Y2004',
#  'Y2005',
#  'Y2006',
#  'Y2007',
#  'Y2008',
#  'Y2009',
#  'Y2010',
#  'Y2011',
#  'Y2012',
#  'Y2013',
#  'Y2014',
#  'Y2015',
#  'Y2016',
#  'Y2017',
#  'Y2018',
#  'Y2019']

# %%
main_df = main_df.rename(columns={'Area Code':'area_code','Area':'area','Months Code':'months_code','Months':'months','Element Code':'element_code','Element':'element','Unit':'unit',})

# %%
main_df.drop(main_df[main_df['element_code']==6078].index, inplace=True)

# %%
main_df
# Out:
#       area_code         area  months_code               months  element_code  \
# 0             2  Afghanistan         7001              January          7271
# 2             2  Afghanistan         7002             February          7271
# 4             2  Afghanistan         7003                March          7271
# 6             2  Afghanistan         7004                April          7271
# 8             2  Afghanistan         7005                  May          7271
# ...         ...          ...          ...                  ...           ...
# 9646       5873         OECD         7016          DecJanFeb          7271
# 9648       5873         OECD         7017          MarAprMay          7271
# 9650       5873         OECD         7018          JunJulAug          7271
# 9652       5873         OECD         7019          SepOctNov          7271
# 9654       5873         OECD         7020  Meteorological year          7271
#
#                  element unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0     Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 2     Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 4     Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
# 6     Temperature change   °C -1.709  0.117  0.919  ...  2.591  1.712  1.417
# 8     Temperature change   °C  1.412 -0.092 -0.690  ...  1.419  3.643  0.909
# ...                  ...  ...    ...    ...    ...  ...    ...    ...    ...
# 9646  Temperature change   °C  0.561 -0.362 -0.222  ...  1.272  0.770  1.709
# 9648  Temperature change   °C -0.038 -0.189  0.141  ...  1.742  0.390  1.442
# 9650  Temperature change   °C  0.101  0.052 -0.047  ...  1.012  0.954  1.061
# 9652  Temperature change   °C  0.036  0.461  0.665  ...  0.958  1.106  0.885
# 9654  Temperature change   °C  0.165 -0.009  0.134  ...  1.246  0.805  1.274
#
#       Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0     1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 2     1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 4     2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
# 6    -0.052  0.585  1.589  0.980  1.252  1.442  0.899
# 8     1.201  0.959  1.862  3.246  3.280  0.855  0.647
# ...     ...    ...    ...    ...    ...    ...    ...
# 9646  1.327  0.686  1.307  2.636  1.884  1.453  1.527
# 9648  0.475  0.778  1.191  1.928  1.237  1.241  1.352
# 9650  1.119  0.779  0.958  1.303  1.081  1.078  1.078
# 9652  1.041  0.999  1.670  1.535  1.194  0.581  1.233
# 9654  0.991  0.811  1.282  1.850  1.349  1.088  1.297
#
# [4828 rows x 66 columns]

# %%
months =['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
temp_months = main_df[main_df['months'].isin(months)]

# %%
temp_months
# Out:
#       area_code         area  months_code     months  element_code  \
# 0             2  Afghanistan         7001    January          7271
# 2             2  Afghanistan         7002   February          7271
# 4             2  Afghanistan         7003      March          7271
# 6             2  Afghanistan         7004      April          7271
# 8             2  Afghanistan         7005        May          7271
# ...         ...          ...          ...        ...           ...
# 9636       5873         OECD         7008     August          7271
# 9638       5873         OECD         7009  September          7271
# 9640       5873         OECD         7010    October          7271
# 9642       5873         OECD         7011   November          7271
# 9644       5873         OECD         7012   December          7271
#
#                  element unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0     Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 2     Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 4     Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
# 6     Temperature change   °C -1.709  0.117  0.919  ...  2.591  1.712  1.417
# 8     Temperature change   °C  1.412 -0.092 -0.690  ...  1.419  3.643  0.909
# ...                  ...  ...    ...    ...    ...  ...    ...    ...    ...
# 9636  Temperature change   °C  0.064  0.130  0.036  ...  1.084  1.277  1.143
# 9638  Temperature change   °C  0.040 -0.050  0.260  ...  0.822  1.318  1.370
# 9640  Temperature change   °C  0.090  0.765  1.305  ...  0.964  1.117  0.544
# 9642  Temperature change   °C -0.023  0.668  0.429  ...  1.088  0.882  0.741
# 9644  Temperature change   °C -0.576  0.258 -0.362  ...  0.590  1.874  0.934
#
#       Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0     1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 2     1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 4     2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
# 6    -0.052  0.585  1.589  0.980  1.252  1.442  0.899
# 8     1.201  0.959  1.862  3.246  3.280  0.855  0.647
# ...     ...    ...    ...    ...    ...    ...    ...
# 9636  1.169  0.743  0.900  1.175  0.971  0.854  1.034
# 9638  1.477  0.964  1.289  1.337  1.291  0.757  1.542
# 9640  1.321  1.675  1.658  0.916  1.413  0.622  1.127
# 9642  0.326  0.357  2.063  2.353  0.878  0.364  1.030
# 9644 -0.324  1.994  2.652  0.809  1.635  2.187  2.432
#
# [3408 rows x 66 columns]

# %%
plt.figure(figsize=(22,5))
sns.lineplot(x='months',y='Y1961', data=temp_months, label='Y1961')
sns.lineplot(x='months',y='Y1971', data=temp_months, label='Y1971')
sns.lineplot(x='months',y='Y1981', data=temp_months, label='Y1981')
sns.lineplot(x='months',y='Y1991', data=temp_months, label='Y1991')
sns.lineplot(x='months',y='Y2001', data=temp_months, label='Y2001')
sns.lineplot(x='months',y='Y2011', data=temp_months, label='Y2011')
sns.lineplot(x='months',y='Y2019', data=temp_months, label='Y2019')
plt.xlabel('months')
plt.ylabel('Temperature change(C)')
plt.title('Temperature change Worldwide last few decades')
plt.show()
